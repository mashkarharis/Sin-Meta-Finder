# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import translators as ts
import translators.server as tss
import json
# Out:
# Using state Western Province server backend.

# %%
songs = pd.read_excel("0. Manually Collected Metahpor Data.xlsx")
songs.head()
# Out:
#     ID                   Name                                           YT  \
# 0  1.0       Ran Kurahan Mala  https://www.youtube.com/watch?v=T-GXCAku5Xc
# 1  NaN                    NaN                                          NaN
# 2  2.0  Adambarai Baluwamanam  https://www.youtube.com/watch?v=xBofgoNnAcg
# 3  3.0             Sulanga Se  https://www.youtube.com/watch?v=IryBitrtMbw
# 4  4.0         Hinahenne Mung  https://www.youtube.com/watch?v=K9VtrFOuyc8
#
#                                          Scrape Link              Author  \
# 0  https://lyrics-lk.com/song/bathiya-and-santhus...  Bathiya | Santhush
# 1                                                NaN                 NaN
# 2  https://www.songlyrics.com/surenie-de-mel-feat...                Iraj
# 3  https://www.google.com/search?q=Sulanga+Se+lyr...          Centigradz
# 4  https://lyrics-lk.com/song/ranidu-lankage/hine...              Ranidu
#
# ...

# %%
song_dict = None
with open("1. output.json",'r') as json_file:
    song_dict = json.load(json_file)

links = list(songs['YT'].dropna())
i=0
for link in links:
    song_dict[i]["youtube_link"]=str(link)
    song_dict[i]["name"]=song_dict[i]["name"].strip()
    i+=1
song_dict
# Out:
# [{'id': '1',
#   'name': 'රන් කුරහන් මල',
#   'youtube_link': 'https://www.youtube.com/watch?v=T-GXCAku5Xc'},
#  {'id': '2',
#   'name': 'අඩම්බරයි බලුවමනම්',
#   'youtube_link': 'https://www.youtube.com/watch?v=xBofgoNnAcg'},
#  {'id': '3',
#   'name': 'සුලංගා සේ',
#   'youtube_link': 'https://www.youtube.com/watch?v=IryBitrtMbw'},
#  {'id': '4',
#   'name': 'හිනහේනේ මන්',
#   'youtube_link': 'https://www.youtube.com/watch?v=K9VtrFOuyc8'},
#  {'id': '5',
#   'name': 'රෙස් විදෙනා සමානාලියක',
#   'youtube_link': 'https://www.youtube.com/watch?v=GW4APZftzEU'},
#  {'id': '6',
#   'name': 'දම්පතා හන්දාව',
#   'youtube_link': 'https://www.youtube.com/watch?v=APgDFNJqoCk'},
#  {'id': '7',
#   'name': 'රන් වන් මල දම්',
#   'youtube_link': 'https://www.youtube.com/watch?v=28oPwzIbAyY'},
#  {'id': '8',
#   'name': 'හිරු මේකි යෑයි නීලා අහස්',
#   'youtube_link': 'https://www.youtube.com/watch?v=kPUV1cGpo48'},
#  {'id': '9',
#   'name': 'සඳවතියෙ',
# ...

# %%
authors_en = set()

for names in songs['Author'].dropna():
    name_list = names.split("|")
    for name in name_list:
        authors_en.add(name.strip())
authors_en
# Out:
# {'6th Lane',
#  'AKA',
#  'Ajith Bandara',
#  'Amila Perera',
#  'Ashanthi',
#  'Athula',
#  'BK',
#  'Bachi Susan',
#  'Bathiya',
#  'Centigradz',
#  'Chamika Sirimanna',
#  'Charith Abesinghe',
#  'Chinthy',
#  'Daddy',
#  'Damith Asanka',
#  'Doctor Band',
#  'Dtap',
#  'Dushan Jayathilake',
#  'Dushyanth',
#  'Eranga',
#  'Eternity',
#  'Funky Dirt',
#  'Gayantha Wijayarathne',
#  'Haroon',
#  'Hasanjith',
#  'IRAJ',
#  'Indrachapa Liyanage',
#  'Infass',
#  'Iraj',
#  'Irusha',
#  'Jaya Sri',
#  'Kasun Kalhara',
#  'Kaveesha',
#  'Keerthi Pasquel',
#  'Killer B',
#  'Krishan',
#  'Kushani',
#  'La Signore (Lahiru Perera)',
#  'Lakshan',
#  'Lakshitha',
#  'Madusshan',
#  'Mahesh',
#  'Malika',
#  'Malith Perera',
#  'Meena Prashadini',
#  'Mihindu Ariyaratne',
#  'Multiple Artists',
#  'Multistyle',
#  'Nirosha Wirajini',
#  'OneStepAhead',
#  'Peshala',
#  'Prasanga',
#  'Prihan',
#  'Rakitha',
#  'Ranidu',
#  'Ravi HaNs',
#  'Ravindra Meegamarachchi',
#  'Romesh',
#  'Roony',
# ...

# %%
# map = {}
# from_language, to_language = 'en', 'si'
# for name_en in authors_en:
#     name_sin = tss.itranslate(name_en.strip(), from_language, to_language).strip()
#     map[name_en]=name_sin
# map

# %%
resolved = {'Rukshan': 'රුක්ශාන්',
 'Sarangan Sri': 'සාරංගන් ශ්රී',
 'Nirosha Wirajini': 'නිරෝෂා විරාජිනී',
 'Chamika Sirimanna': 'චිිිීිම්කා සිරිමාන්න',
 'Dushyanth': 'දුෂයන්ත්',
 'BK': 'බීකේ',
 'Kaveesha': 'කවීෂා',
 'Shihan Mihiranga': 'ශිහාන් මිහිරංග',
 'Prasanga': 'ප්‍රරසංග',
 'Santhush': 'සංතුෂ්',
 'Ravindra Meegamarachchi': 'රවීන්ද්ර මීගමආරච්චි',
 'Irusha': 'ඉරුෂා',
 'Prihan': 'ප්රිහාන්',
 'Indrachapa Liyanage': 'ඉන්ද්රචාපා ලියනගේ',
 'OneStepAhead': 'වන් ස්ටෙප් අහෙඩ්',
 'Rakitha': 'රඛිත',
 'Multiple Artists': 'බහු කලාකරුවන්',
 'Iraj': 'ඉරාජ්',
 'Lakshan': 'ලක්ෂාන්',
 'Killer B': 'කිලර් බී',
 'Daddy': 'ඩැඞී',
 'AKA': 'ඒ.කේ.ඒ',
 'Jaya Sri': 'ජය ශ්රී',
 'Gayantha Wijayarathne': 'ගයන්ත විජයරත්න',
 'Theekshana Anuradha':'තික්ෂන අනුරාධ',
 'Mahesh': 'මහේෂ්',
 'Wayo': 'වායෝ',
 'Ravi HaNs': 'රවී හාන්ස්',
 '6th Lane': '6ත් ලේන්',
 'Eternity': 'එටෙර්නිටි',
 'Bathiya': 'භාතිය',
 'Sirasa Superstar Contestants': 'සිරස සුපර්ස්ටාර් තරගකරුවන්',
 'Peshala': 'පේෂල',
 'Madusshan': 'මදුෂාන්',
 'Umaria Sinhawansa': 'උමාරියා සිංහවංශ',
 'Charith Abesinghe': 'චරිත් අබේසිංහ',
 'Doctor Band': 'ඩොක්ටර් බෑන්ඩ්',
 'Infass': 'ඉන්ෆාස්',
 'Ranidu': 'රනිදු',
 'Siththa': 'සිත්ත',
 'Mihindu Ariyaratne': 'මිහිඳු ආරියරත්න',
 'Damith Asanka': 'දමිත් අසංක',
 'Bachi Susan': 'බාචි සුසාන්',
 'Haroon': 'හරූන්',
 'Malika': 'මාලිකා',
 'Multistyle': 'මල්ටිස්ටයිල්',
 'Lakshitha': 'ලක්ෂිත',
 'Ashanthi': 'අශාන්ති',
 'Centigradz': 'සෙන්ටිග්රේඩ්ස්',
 'Eranga': 'එරංග',
 'Roony': 'රෝනි',
 'Shan Hassim': 'ෂාන් හසිම්',
 'Keerthi Pasquel': 'කීර්ති පැස්කුවෙල්',
 'Shashika': 'ශෂිකා',
 'Malith Perera': 'මලිත් පෙරේරා',
 'Sachin': 'සචින්',
 'Amila Perera': 'අමිලා පෙරේරා',
 'Kasun Kalhara': 'කසුන් කල්හාර',
 'Rukman Asitha': 'රුක්මන් අසිත',
 'Funky Dirt': 'ෆන්කි ඩර්ට්',
 'Kushani': 'කුෂානි',
 'Samitha Mudunkotuwa': 'සමිතා මුදුන්කොටුව',
 'Ajith Bandara': 'අජිත් බණ්ඩාර',
 'Meena Prashadini': 'මීනා ප්රශාදිනී',
 'La Signore (Lahiru Perera)': 'ලා සිග්නොර් (ලහිරු පෙරේරා)',
 'Dushan Jayathilake': 'දුෂාන් ජයතිලක',
 'Uresha Rvihara': 'උරේෂා රවිහාරි',
 'Dtap': 'ඩීටැප්',
 'Ruwan Hettiarachchi': 'රුවන් හෙට්ටිආරච්චි',
 'Romesh': 'රොමේෂ්',
 'Krishan': 'ක්රිෂාන්',
 'Tehan Perera': 'ටෙහාන් පෙරේරා',
 'Athula': 'අතුල',
 'Hasanjith': 'හසන්ජිත්',
 'Shanika Madumali': 'ශානිකා මධුමාලි',
 'Shalitha': 'ශාලිත',
 'Surendra Perera': 'සුරේන්ද්ර පෙරේරා',
 'Chinthy': 'චින්ති',
 'IRAJ': 'ඉරාජ්'}

# %%
j=0
for names in songs['Author'].dropna():
    name_list = names.split("|")
    sin_name_list = [resolved[i.strip()].strip() for i in name_list]
    song_dict[j]['singers'] = sin_name_list
    j+=1
song_dict
# Out:
# [{'id': '1',
#   'name': 'රන් කුරහන් මල',
#   'youtube_link': 'https://www.youtube.com/watch?v=T-GXCAku5Xc',
#   'singers': ['භාතිය', 'සංතුෂ්']},
#  {'id': '2',
#   'name': 'අඩම්බරයි බලුවමනම්',
#   'youtube_link': 'https://www.youtube.com/watch?v=xBofgoNnAcg',
#   'singers': ['ඉරාජ්']},
#  {'id': '3',
#   'name': 'සුලංගා සේ',
#   'youtube_link': 'https://www.youtube.com/watch?v=IryBitrtMbw',
#   'singers': ['සෙන්ටිග්රේඩ්ස්']},
#  {'id': '4',
#   'name': 'හිනහේනේ මන්',
#   'youtube_link': 'https://www.youtube.com/watch?v=K9VtrFOuyc8',
#   'singers': ['රනිදු']},
#  {'id': '5',
#   'name': 'රෙස් විදෙනා සමානාලියක',
#   'youtube_link': 'https://www.youtube.com/watch?v=GW4APZftzEU',
#   'singers': ['භාතිය', 'සංතුෂ්']},
#  {'id': '6',
#   'name': 'දම්පතා හන්දාව',
#   'youtube_link': 'https://www.youtube.com/watch?v=APgDFNJqoCk',
#   'singers': ['සචින්', 'රඛිත', 'එරංග']},
#  {'id': '7',
#   'name': 'රන් වන් මල දම්',
#   'youtube_link': 'https://www.youtube.com/watch?v=28oPwzIbAyY',
# ...

# %%
for song in song_dict:
    song['metaphors'] = []
song_dict
# Out:
# [{'id': '1',
#   'name': 'රන් කුරහන් මල',
#   'youtube_link': 'https://www.youtube.com/watch?v=T-GXCAku5Xc',
#   'singers': ['භාතිය', 'සංතුෂ්'],
#   'metaphors': []},
#  {'id': '2',
#   'name': 'අඩම්බරයි බලුවමනම්',
#   'youtube_link': 'https://www.youtube.com/watch?v=xBofgoNnAcg',
#   'singers': ['ඉරාජ්'],
#   'metaphors': []},
#  {'id': '3',
#   'name': 'සුලංගා සේ',
#   'youtube_link': 'https://www.youtube.com/watch?v=IryBitrtMbw',
#   'singers': ['සෙන්ටිග්රේඩ්ස්'],
#   'metaphors': []},
#  {'id': '4',
#   'name': 'හිනහේනේ මන්',
#   'youtube_link': 'https://www.youtube.com/watch?v=K9VtrFOuyc8',
#   'singers': ['රනිදු'],
#   'metaphors': []},
#  {'id': '5',
#   'name': 'රෙස් විදෙනා සමානාලියක',
#   'youtube_link': 'https://www.youtube.com/watch?v=GW4APZftzEU',
#   'singers': ['භාතිය', 'සංතුෂ්'],
#   'metaphors': []},
#  {'id': '6',
#   'name': 'දම්පතා හන්දාව',
#   'youtube_link': 'https://www.youtube.com/watch?v=APgDFNJqoCk',
#   'singers': ['සචින්', 'රඛිත', 'එරංග'],
# ...

# %%
json_object = json.dumps(song_dict)
 
with open("2. output.json", "w") as outfile:
    outfile.write(json_object)
